# %%
import pandas as pd
dataset=pd.read_csv("ProsKidney_Disease.csv")

# %%
dataset
# Out:
#      Unnamed: 0     id    bp     sg   al   su         bgr    bu   sc  \
# 0             0    0.0  80.0  1.020  1.0  0.0  121.000000  36.0  1.2
# 1             1    1.0  50.0  1.020  4.0  0.0  148.036517  18.0  0.8
# 2             2    2.0  80.0  1.010  2.0  3.0  423.000000  53.0  1.8
# 3             3    3.0  70.0  1.005  4.0  0.0  117.000000  56.0  3.8
# 4             4    4.0  80.0  1.010  2.0  0.0  106.000000  26.0  1.4
# ..          ...    ...   ...    ...  ...  ...         ...   ...  ...
# 395         395  395.0  80.0  1.020  0.0  0.0  140.000000  49.0  0.5
# 396         396  396.0  70.0  1.025  0.0  0.0   75.000000  31.0  1.2
# 397         397  397.0  80.0  1.020  0.0  0.0  100.000000  26.0  0.6
# 398         398  398.0  60.0  1.025  0.0  0.0  114.000000  50.0  1.0
# 399         399  399.0  80.0  1.025  0.0  0.0  131.000000  18.0  1.1
#
#             sod  ...  pcv    wc   rc  htn   dm cad appet   pe  ane  \
# 0    137.528754  ...   44  7800  5.2  yes  yes  no  good   no   no
# ...

# %%
dataset.isna().sum()
# Out:
# Unnamed: 0        0
# id                0
# bp                0
# sg                0
# al                0
# su                0
# bgr               0
# bu                0
# sc                0
# sod               0
# pot               0
# hemo              0
# rbc               0
# pc                0
# pcc               0
# ba                0
# pcv               0
# wc                0
# rc                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64
